# %%
# Import dependencies
import requests
from config import spotify_token
import pandas as pd
import numpy as np
import time
import re

# %%
spotify_token = ''

# %%
base_url = 'https://api.spotify.com'
headers_dict = {'Content-Type': 'application/json', 
                'Authorization': f'Bearer {spotify_token}',
                'country': 'US'}

# %%
# Create a list of all the 50 category ids
t0 = time.time()
query_url = base_url + f'/v1/browse/categories?limit=50'
results = requests.get(query_url, headers=headers_dict).json()

categories_list = []
for id, category in enumerate(results['categories']['items']):
    categories_list.append(category['id'])

t1 = time.time()
print(f'Run time: {t1-t0} seconds')
categories_list
# Out:
# Run time: 0.13297104835510254 seconds
# ['toplists',
#  '2020',
#  'holidays',
#  'hiphop',
#  'pop',
#  'country',
#  'workout',
#  'at_home',
#  'rock',
#  'latin',
#  'mood',
#  'rnb',
#  'jre_podcast',
#  'gaming',
#  'shows_with_music',
#  'focus',
#  'edm_dance',
#  'blackhistorymonth',
#  'chill',
#  'indie_alt',
#  'inspirational',
#  'decades',
#  'instrumental',
#  'alternative',
#  'wellness',
#  'in_the_car',
#  'pride',
#  'party',
#  'sleep',
#  'classical',
#  'jazz',
#  'roots',
#  'soul',
#  'sessions',
#  'dinner',
#  'romance',
#  'kpop',
#  'punk',
#  'regional_mexican',
#  'popculture',
#  'blues',
#  'arab',
#  'desi',
#  'radar',
#  'anime',
#  'thirdparty',
#  'afro',
#  'comedy',
#  'metal',
#  'caribbean']

# %%
# Create a list of filtered categories
filtered_categories = ['pop', 'hiphop', 'metal', 'rock', 'jazz', 'rnb',
                       'romance', 'soul', 'indie_alt', 'classical', 'blues', 'funk',
                       'punk', 'country']
other = ['edm_dance', 'party', 'family', 'caribbean', 'afro']

# %%
# Create a dictionary of categories and playlists
t0 = time.time()
category_playlist_ids = {}
for cat in filtered_categories:
    query_url = base_url + f'/v1/browse/categories/{cat}/playlists?limit=50'
    playlists = []
    results = requests.get(query_url, headers=headers_dict).json()
    try: 
        for id, playlist in enumerate(results['playlists']['items']):
            playlists.append(playlist['id'])
        if len(playlists) > 0:
            category_playlist_ids[cat] = playlists
    except:
        print(f'No playlists for category: {cat}')
print(f'Playlists found for {len(category_playlist_ids)} categories.')
t1 = time.time()
print(f'Run time: {t1-t0} seconds')
# Out:
# Playlists found for 15 categories.
# Run time: 2.300999879837036 seconds

# %%
# Get the number of playlists for each category
for cat in category_playlist_ids:
    print(cat, len(category_playlist_ids[cat]))
# Out:
# pop 2
# hiphop 8
# metal 11
# rock 19
# edm_dance 17
# jazz 8
# rnb 12
# romance 12
# soul 9
# indie_alt 11
# classical 50
# blues 1
# funk 5
# punk 2
# country 13

# %%
# Create a list of playlists from the Spotify API
api_playlists = []
for cat in category_playlists:
    for playlist in category_playlists[cat]:
        # Print any duplicates
        if playlist in api_playlists:
            print(cat, playlist)
    api_playlists.extend(category_playlists[cat])
print(len(api_playlists))
len(set(api_playlists))
# Out:
# 341
# 341

# %%
##################################################
# MANUALLY create a dictionary of categories and playlists
pop_playlists = ['37i9dQZF1DWUa8ZRTfalHk', '37i9dQZF1DX5gQonLbZD9s', '37i9dQZF1DWTwnEm1IYyoj',
                     '37i9dQZF1DX8S0uQvJ4gaa', '37i9dQZF1DXaiEFNvQPZrM', '37i9dQZF1DX1V02WRNSlSH',
                     '37i9dQZF1DXbIbVYph0Zr5', '37i9dQZF1DX2C6Zlz76Dq4', '37i9dQZF1DWXdiK4WAVRUW',
                     '37i9dQZF1DWZBCPUIUs2iR', '37i9dQZF1DX6rVyqO2FaN8', '37i9dQZF1DWW7RgkOJG32Y',
                     '37i9dQZF1DX49poIUZYXp7', '37i9dQZF1DWYiR2Uqcon0X', '37i9dQZF1DWXepGEFFmQXJ',
                     '37i9dQZF1DX13kFuGnInkY', '37i9dQZF1DWU2LcZVHsTdv', '37i9dQZF1DX3RCeShx2suK',
                     '37i9dQZF1DWXi7h4mmmkzD', '37i9dQZF1DX9hWdQ46pHPo', '37i9dQZF1DXdmMcgFhLQ8u',
                     '37i9dQZF1DWTQrwBpetTXv', '37i9dQZF1DX8ZfTXESa5KP', '37i9dQZF1DWSCp8Clax7tf',
                     '37i9dQZF1DWVn8zvR5ROMB', '37i9dQZF1DWYUfsq4hxHWP', '37i9dQZF1DX3ph0alWhOXm',
                     '37i9dQZF1DX5OrO2Jxuvdn', '37i9dQZF1DXaB64wwvEuUo', '37i9dQZF1DX28e329hmxEg']
category_playlists = {}
filtered_categories = ['pop', 'hiphop', 'metal', 'rock', 'edm_dance', 'jazz', 'rnb',
                       'romance', 'soul', 'indie_alt', 'classical', 'blues', 'funk',
                       'punk', 'country']     
category_playlists['pop'] = pop_playlists
category_playlists['hiphop'] = hiphop_playlists
category_playlists['metal'] = metal_playlists
category_playlists['rock'] = rock_playlists
category_playlists['jazz'] = jazz_playlists
category_playlists['rnb'] = rnb_playlists
category_playlists['romance'] = romance_playlists
category_playlists['soul'] = soul_playlists
category_playlists['indie_alt'] = indie_alt_playlists
category_playlists['classical'] = category_playlist_ids['classical']
category_playlists['blues'] = blues_playlists
category_playlists['funk'] = funk_playlists
category_playlists['punk'] = punk_playlists
category_playlists['country'] = country_playlists

# %%
# Get the number of playlists for each category
for cat in category_playlists:
    print(cat, len(category_playlists[cat]))
# Out:
# pop 20
# hiphop 21
# metal 27
# rock 38
# jazz 30
# rnb 11
# romance 9
# soul 14
# indie_alt 19
# classical 50
# blues 23
# funk 17
# punk 20
# country 42

# %%
# Check that every playlist is unique
playlists = []
for cat in category_playlists:
    playlists.extend(category_playlists[cat])
print(len(playlists))
len(set(playlists))
# Out:
# 341
# 341

# %%
##################################################
# MANUALLY create lists of other playlists
pop_playlists = ['37i9dQZF1DX2L0iB23Enbq', '37i9dQZF1DX4JAvHpjipBk', '37i9dQZF1DXbYM3nMM0oPk',
                 '37i9dQZF1DX5gQonLbZD9s', '37i9dQZF1DWWvvyNmW9V9a', '37i9dQZF1DX6OgmB2fwLGd',
                 '37i9dQZF1DX0b1hHYQtJjp', '37i9dQZF1DWTwnEm1IYyoj', '37i9dQZF1DWYs83FtTMQFw',
                     '37i9dQZF1DWZBCPUIUs2iR', '37i9dQZF1DX6rVyqO2FaN8', '37i9dQZF1DWW7RgkOJG32Y',
                     '37i9dQZF1DX49poIUZYXp7', '37i9dQZF1DWYiR2Uqcon0X', '37i9dQZF1DWXepGEFFmQXJ',
                     '37i9dQZF1DX13kFuGnInkY', '37i9dQZF1DWU2LcZVHsTdv', '37i9dQZF1DX3RCeShx2suK',
                     '37i9dQZF1DWXi7h4mmmkzD', '37i9dQZF1DX9hWdQ46pHPo', '37i9dQZF1DXdmMcgFhLQ8u',
                     '37i9dQZF1DWTQrwBpetTXv', '37i9dQZF1DX8ZfTXESa5KP', '37i9dQZF1DWSCp8Clax7tf',
                     '37i9dQZF1DWVn8zvR5ROMB', '37i9dQZF1DWYUfsq4hxHWP', '37i9dQZF1DX3ph0alWhOXm',
                     '37i9dQZF1DX5OrO2Jxuvdn', '37i9dQZF1DXaB64wwvEuUo', '37i9dQZF1DX28e329hmxEg']
country_love = '37i9dQZF1DX8WMG8VPSOJC'

# %%
# Create a DataFrame of song names, artists, and categories
t0 = time.time()
song_genres_df = pd.DataFrame(columns=['song', 'song_id', 'artist', 'artist_id', 'category'])
index = 0
for category in category_playlists:
    song_count = 0
    # Determine how many songs to get from each playlist
    playlists = category_playlists[category]
    for playlist_id in playlists:
        # Get songs from each playlist
        query_url = base_url + f'/v1/playlists/{playlist_id}/tracks?limit=50'
        results = requests.get(query_url, headers=headers_dict).json()
        try: 
            # Get the song, artist, and genres for each song
            for id, item in enumerate(results['items']):
                song = item['track']['name']
                song_id = item['track']['id']
                artist = item['track']['artists'][0]['name']
                artist_id = item['track']['artists'][0]['id']
                if song_id not in list(set(song_genres_df['song_id'])):
                    song_genres_df.loc[index] = [song, song_id, artist, artist_id, category]
                    song_count+=1
                    index+=1
        except(Exception) as e:
            print(f'No results for playlist {playlist_id}')
    print(f'Added {song_count} songs for {category} category.')
t1 = time.time()
print(f'Run time: {t1-t0} seconds')
song_genres_df.head()
# Out:
# No results for playlist 37i9dQZF1DX7HOk71GPfSw
# Added 855 songs for pop category.
# No results for playlist 37i9dQZF1DWT5MrZnPU1zD
# Added 882 songs for hiphop category.
# Added 1259 songs for metal category.
# Added 1625 songs for rock category.
# Added 1298 songs for jazz category.
# Added 404 songs for rnb category.
# Added 357 songs for romance category.
# Added 569 songs for soul category.
# No results for playlist 37i9dQZF1DX8CopunbDxgW
# No results for playlist 37i9dQZF1DXdbXrPNafg9d
# Added 813 songs for indie_alt category.
# Added 2203 songs for classical category.
# No results for playlist 37i9dQZF1DXcnkReojaCnV
# Added 925 songs for blues category.
# Added 750 songs for funk category.
# No results for playlist 37i9dQZF1DX7iAOkSHdhFI
# No results for playlist 37i9dQZF1DX7WJ4yDmRK8R
# No results for playlist 37i9dQZF1DXaDzsRodF91I
# Added 811 songs for punk category.
# No results for playlist 37i9dQZF1DX8ZfTXESa5KP
# Added 1461 songs for country category.
# ...

# %%
# Create a list of featured playlists
featured_playlists = []
query_url = base_url + f'/v1/browse/featured-playlists?limit=50'
results = requests.get(query_url, headers=headers_dict).json()
for item in results['playlists']['items']:
    featured_playlists.append((item['name'], item['id']))
featured_playlists
# Out:
# [('Wake Up Gently', '37i9dQZF1DX7cZxYLqLUJl'),
#  ('Morning Motivation', '37i9dQZF1DXc5e2bJhV6pu'),
#  ("Today's Top Hits", '37i9dQZF1DXcBWIGoYBM5M'),
#  ('Bliss', '37i9dQZF1DX4bSrsRWE9cd'),
#  ('Meditate to the Sounds of Nature', '37i9dQZF1DX1tuUiirhaT3'),
#  ('Rock Classics', '37i9dQZF1DWXRqgorJj26U'),
#  ('Mellow Morning', '37i9dQZF1DWWzVPEmatsUB'),
#  ('Lo-Fi Beats', '37i9dQZF1DWWQRwui0ExPn'),
#  ('Easy', '37i9dQZF1DX2czWA9hqErK'),
#  ('Chill Hits', '37i9dQZF1DX4WYpdgoIcn6'),
#  ('Jazz Vibes', '37i9dQZF1DX0SM0LYsmbMT'),
#  ('Soft Pop Hits', '37i9dQZF1DWTwnEm1IYyoj')]

# %%
# Create a dictionary of genres for each artist
t0 = time.time()
artist_genres = {}
count = 0
for artist_id in song_genres_df['artist_id'].unique():
    query_url = base_url + f'/v1/artists/{artist_id}'
    artist = requests.get(query_url, headers=headers_dict).json()
    genres = artist['genres']
    genres = list(set([genre.split()[0] for genre in genres]))
    artist_genres[artist_id] = genres
    if genres == []:
        artist_name = artist['name']
        count+=1

t1 = time.time()
print(f'Run time: {t1-t0} seconds')
print(f'No genres found for {count} artists.')
len(artist_genres)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-509fa1c973e7> in <module>
#       5 for artist_id in song_genres_df['artist_id'].unique():
#       6     query_url = base_url + f'/v1/artists/{artist_id}'
# ----> 7     artist = requests.get(query_url, headers=headers_dict).json()
#       8     genres = artist['genres']
#       9     genres = list(set([genre.split()[0] for genre in genres]))
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
# Add a column of artist genres
genre_column = []
for artist_id in song_genres_df['artist_id']:
    genre_column.append(artist_genres[artist_id])
song_genres_df['genres'] = genre_column
song_genres_df.head()

# %%
# Create a function that adds a column of filtered genres
def filter_genres(song_genres_df):
    # Create a non-destructive copy
    song_genres_df = pd.DataFrame(song_genres_df)
    
    # Create a list of all genres
    genre_list = []
    genre_column = song_genres_df['genres']
    for artist_genres in genre_column:
        genre_list.extend(artist_genres)
    genre_list = list(set(genre_list))
    print(f'{len(genre_list)} unique genres found.')
    
    # Find most popular genres
    popular_genres = dict.fromkeys(genre_list, 0)
    for artist_genres in genre_column:
        for genre in artist_genres:
            popular_genres[genre]+=1
    popular_genres = dict(sorted(popular_genres.items(), key=lambda kv: kv[1], reverse=True))
    
    # Create a list of genres that applies to all songs
    t0 = time.time()
    common_genres = []
    song_index_list = []
    for index, row in song_genres_df.iterrows():
        if len(row['genres']) == 0:
            song_index_list.append(index)
        elif (len(row['genres']) == 1):
            genre = row['genres'][0]
            if genre not in common_genres:
                new_indeces = list(song_genres_df[pd.DataFrame(song_genres_df.genres.tolist()).isin(np.tile(genre, len(song_genres_df))).any(1).values].index)
                song_index_list.extend(new_indeces)
                song_index_list = list(set(song_index_list))
                common_genres.append(genre)
    counter = 0
    while len(song_index_list) < len(song_genres_df):
        start = len(song_index_list)
        new_genre = list(popular_genres.keys())[counter]    
        while new_genre in common_genres:
            counter+=1
            new_genre = list(popular_genres.keys())[counter]
        new_indeces = list(song_genres_df[pd.DataFrame(song_genres_df.genres.tolist()).isin(np.tile(new_genre, len(song_genres_df))).any(1).values].index)
        song_index_list.extend(new_indeces)
        song_index_list = list(set(song_index_list))
        if start != len(song_index_list):
            common_genres.append(new_genre)
        counter+=1
    t1 = time.time()
    print(f'Run time to find common genres: {t1-t0} seconds')
    print(f'All songs are encompassed by {len(common_genres)} genres.')
        
    # Drop genres that only appear once
    genres_to_drop = []
    for genre in popular_genres:
        if popular_genres[genre] == 1:
            genres_to_drop.append(genre)
    for genre in genres_to_drop:
        if genre in common_genres:
            common_genres.remove(genre)
    print(f'{len(genres_to_drop)} singular genres found.')
        
    # Add a column of filtered genres
    filtered_genres = []
    for artist_genres in genre_column:
        filtered = []
        for genre in artist_genres:
            if genre in common_genres:
                filtered.append(genre)
        filtered_genres.append(filtered)
    song_genres_df['filtered_genres'] = filtered_genres
    
    return song_genres_df

# %%
# Run the filter_genres function
song_genres_df = filter_genres(song_genres_df)
song_genres_df.head()
# Out:
# 861 unique genres found.
# Run time to find common genres: 22.85003089904785 seconds
# All songs are encompassed by 379 genres.
# 163 singular genres found.
#                                     song                 song_id  \
# 0                                 willow  0lx2cLdOt3piJbcaXIV74f
# 1  Stay Next To Me (with Chelsea Cutler)  6SGG5AxHShqSYiV9fCWpZz
# 2                            WITHOUT YOU  27OeeYzk6klgBh83TSvGMA
# 3                             Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 4                                 r u ok  7rq1zCf90CnU7OalBLIgNp
#
#           artist               artist_id category  \
# 0   Taylor Swift  06HL4z0CvFAxyc27GXpf02      pop
# 1     Quinn XCII  3ApUX1o6oSz321MMECyIYd      pop
# 2  The Kid LAROI  2tIP7SsRs7vjIcLrU85W8J      pop
# 3  Glass Animals  4yvcSjfu4PC0CYQyLy4wSq      pop
# 4     Tate McRae  45dkTj5sMRSjrmBSBeiHym      pop
#
#                                 genres           filtered_genres  \
# ...

# %%
# Create a list of filtered genres
filtered_genres = []
for genres in song_genres_df['filtered_genres']:
    filtered_genres.extend(genres)
filtered_genres = list(set(filtered_genres))
len(filtered_genres)
# Out:
# 349

# %%
# Get the most popular genres for each category
category_genres = {}
for category in filtered_categories:
    genres = []
    for index, row in song_genres_df[song_genres_df['category']==category].iterrows():
        genres.extend(row['filtered_genres'])
    unique_genres = list(set(genres))
    genre_counts = []
    for genre in unique_genres:
        genre_counts.append((genre, genres.count(genre)))
    category_genres[category] = sorted(genre_counts, key = lambda x: x[1], reverse=True)[0:5]
category_genres
# Out:
# {'pop': [('pop', 394),
#   ('indie', 202),
#   ('dance', 183),
#   ('electropop', 143),
#   ('uk', 99)],
#  'hiphop': [('rap', 397),
#   ('hip', 351),
#   ('pop', 262),
#   ('trap', 225),
#   ('southern', 172)],
#  'metal': [('metal', 444),
#   ('alternative', 322),
#   ('rock', 277),
#   ('hard', 270),
#   ('nu', 244)],
#  'rock': [('rock', 798),
#   ('modern', 379),
#   ('classic', 356),
#   ('alternative', 353),
#   ('album', 289)],
#  'jazz': [('jazz', 485),
#   ('contemporary', 394),
#   ('cool', 229),
#   ('vocal', 228),
#   ('soul', 174)],
#  'rnb': [('pop', 234),
#   ('r&b', 224),
#   ('dance', 181),
#   ('hip', 148),
#   ('neo', 129)],
#  'romance': [('pop', 127),
#   ('soft', 108),
#   ('mellow', 96),
#   ('dance', 91),
#   ('classic', 61)],
#  'soul': [('soul', 252),
#   ('motown', 228),
#   ('quiet', 203),
#   ('funk', 185),
#   ('classic', 183)],
#  'indie_alt': [('indie', 322),
#   ('alternative', 221),
#   ('new', 200),
#   ('art', 186),
#   ('rock', 185)],
# ...

# %% [markdown]
# # Cleaning genres

# %%
# Create a list of new genres
t0 =  time.time()
new_genres = []
cat_genre_dict = {'pop': ['pop', 'electropop', 'la'], # 'indie'
                  'hiphop': ['rap', 'trap', 'hip', 'lo-fi', 'underground', 'sad'], # 'indie', 'pop'
                  'metal': ['metal', 'progressive', 'industrial', 'melodic'], # 'alternative', 'rock'
                  'rock': ['rock', 'emo', 'psychedelic', 'post-grunge'], # 'pop', 'alternative'
                  'jazz': ['jazz', 'smooth', 'gypsy'], # 'indie'
                  'rnb': ['r&b', 'chill'], # 'pop', 'indie'
                  'romance': ['soft'], # 'pop'
                  'soul': ['soul', 'neo', 'motown'], # 'indie'
                  'indie_alt': ['indie', 'dance', 'alternative'], # 'rock', 'britpop' ?
                  'classical': ['classical', 'soundtrack', 'neo-classical', 'early', 'sleep', 'compositional', 'minimalism'], # 'british', 'american' ?
                  'blues': ['blues', 'rhythm', 'jump'],
                  'funk': ['funk', 'disco', 'future', 'electric'], # 'jazz'
                  'punk': ['punk', 'riot', 'celtic', 'steampunk', 'screamo', 'anthem'], # 'pop'
                  'country': ['country', 'nashville']} 
for index, row in song_genres_df.iterrows():
    genre_found = False
    category = row['category']
    for genre in cat_genre_dict[category]:
        if genre in row['filtered_genres']:
            genre_found = True
            new_genres.append(category)
            break
    if genre_found == False:
        new_genres.append(None)
t1 = time.time()
print(f'Run time: {t1-t0} seconds')
len(new_genres)
# Out:
# Run time: 1.6907970905303955 seconds
# 14212

# %%
# Check categories of certain genres
genre = ''
genre_df = song_genres_df[pd.DataFrame(song_genres_df.filtered_genres.tolist()).isin(np.tile(genre, len(song_genres_df))).any(1).values]
genre_df[genre_df.isnulsol()['new_genre']]
print(len(genre_df[genre_df.isnull()['new_genre']]))
print(set(genre_df[genre_df.isnull()['new_genre']]['category']))
# Out:
# 0
# set()
# funk 0

# %%
# Get the number of songs without a new genre
new_genres.count(None)
# Out:
# 5706

# %%
# Add a column of new genres
#song_genres_df.insert(7, 'new_genre', new_genres)
song_genres_df['new_genre'] = new_genres
song_genres_df.head()
# Out:
#                                     song                 song_id  \
# 0                                 willow  0lx2cLdOt3piJbcaXIV74f
# 1  Stay Next To Me (with Chelsea Cutler)  6SGG5AxHShqSYiV9fCWpZz
# 2                            WITHOUT YOU  27OeeYzk6klgBh83TSvGMA
# 3                             Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 4                                 r u ok  7rq1zCf90CnU7OalBLIgNp
#
#           artist               artist_id category  \
# 0   Taylor Swift  06HL4z0CvFAxyc27GXpf02      pop
# 1     Quinn XCII  3ApUX1o6oSz321MMECyIYd      pop
# 2  The Kid LAROI  2tIP7SsRs7vjIcLrU85W8J      pop
# 3  Glass Animals  4yvcSjfu4PC0CYQyLy4wSq      pop
# 4     Tate McRae  45dkTj5sMRSjrmBSBeiHym      pop
#
#                                 genres           filtered_genres new_genre  \
# 0                         [dance, pop]              [dance, pop]       pop
# 1             [indie, pop, electropop]  [indie, pop, electropop]       pop
# ...

# %%
# Find genres that are unique to one category
t0 = time.time()
unique_genres = []
for genre in filtered_genres:
    genre_df = song_genres_df[pd.DataFrame(song_genres_df.filtered_genres.tolist()).isin(np.tile(genre, len(song_genres_df))).any(1).values]
    if len(set(genre_df['category'])) == 1:
        unique_genres.append(genre)
t1 = time.time()
print(f'Run time: {t1-t0} seconds')
len(unique_genres)
# Out:
# Run time: 6.581818103790283 seconds
# 59

# %%
# Update new_genre for any song with a unique genre
for index, row in song_genres_df.iterrows():
    for genre in row['filtered_genres']:
        if (genre in unique_genres) & (row['new_genre']==None):
            song_genres_df.loc[index, 'new_genre'] = row['category']

# %%
# Check if there are less songs without new_genre
len(song_genres_df[song_genres_df.isnull()['new_genre']])
# Out:
# 2631

# %%
# Examine songs with no new genre
song_genres_df[song_genres_df.isnull().any(axis=1)].head()

# Get the most popular genres for each category of songs with no new genre
category_genres = {}
for category in filtered_categories:
    genres = []
    for index, row in song_genres_df[song_genres_df.isnull().any(axis=1)][song_genres_df['category']==category].iterrows():
        genres.extend(row['filtered_genres'])
    unique_genres = list(set(genres))
    genre_counts = []
    for genre in unique_genres:
        genre_counts.append((genre, genres.count(genre)))
    category_genres[category] = sorted(genre_counts, key = lambda x: x[1], reverse=True)[0:5]
category_genres
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# {'pop': [('indie', 86),
#   ('modern', 45),
#   ('uk', 30),
#   ('alternative', 13),
#   ('bedroom', 12)],
#  'hiphop': [('indie', 49),
#   ('pop', 41),
#   ('canadian', 30),
#   ('toronto', 13),
#   ('brooklyn', 12)],
#  'metal': [('alternative', 113),
#   ('nu', 97),
#   ('rock', 81),
#   ('rap', 72),
#   ('hard', 48)],
#  'rock': [('modern', 130),
#   ('pop', 100),
#   ('alternative', 84),
#   ('indie', 39),
#   ('nu', 36)],
#  'jazz': [('indie', 57),
#   ('uk', 37),
#   ('neo', 27),
#   ('adult', 21),
#   ('vocal', 19)],
#  'rnb': [('pop', 59),
#   ('indie', 43),
#   ('alternative', 39),
#   ('rap', 23),
#   ('dance', 17)],
#  'romance': [('pop', 113),
#   ('dance', 70),
#   ('neo', 48),
#   ('soul', 26),
#   ('rock', 24)],
#  'soul': [('indie', 44),
#   ('alternative', 35),
#   ('disco', 21),
#   ('quiet', 16),
#   ('post-disco', 12)],
# ...

# %%
# Add a column of new genres
song_genres_df['new_genres'] = new_genre_list
song_genres_df.head()
# Out:
#                                     song                 song_id  \
# 0                                 willow  0lx2cLdOt3piJbcaXIV74f
# 1  Stay Next To Me (with Chelsea Cutler)  6SGG5AxHShqSYiV9fCWpZz
# 2                            WITHOUT YOU  27OeeYzk6klgBh83TSvGMA
# 3                             Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 4                                 r u ok  7rq1zCf90CnU7OalBLIgNp
#
#           artist               artist_id category  \
# 0   Taylor Swift  06HL4z0CvFAxyc27GXpf02      pop
# 1     Quinn XCII  3ApUX1o6oSz321MMECyIYd      pop
# 2  The Kid LAROI  2tIP7SsRs7vjIcLrU85W8J      pop
# 3  Glass Animals  4yvcSjfu4PC0CYQyLy4wSq      pop
# 4     Tate McRae  45dkTj5sMRSjrmBSBeiHym      pop
#
#                                 genres           filtered_genres  \
# 0                         [dance, pop]              [dance, pop]
# 1             [indie, pop, electropop]  [indie, pop, electropop]
# 2                         [australian]              [australian]
# ...

# %%
# Create DataFrame of rows with empty new_genres column
t0 = time.time()
no_new_genres = pd.DataFrame(columns=['song', 'song_id', 'artist', 'artist_id', 'category', 'genres', 'filtered_genres', 'new_genres'])
id = 0
for index, row in song_genres_df.iterrows():
    if row['new_genres'] == []:
        song = row['song']
        song_id = row['song_id']
        artist = row['artist']
        artist_id = row['artist_id']
        category = row['category']
        genres = row['genres']
        filtered_genres = row['filtered_genres']   
        new_genres = row['new_genres']
        no_new_genres.loc[id] = [song, song_id, artist, artist_id, category, genres, filtered_genres, new_genres]
        id+=1
t1 = time.time()
print(f'Run time: {t1-t0} seconds')
no_new_genres.head()
# Out:
# Run time: 18.86404013633728 seconds
#                                               song                 song_id  \
# 0                                      WITHOUT YOU  27OeeYzk6klgBh83TSvGMA
# 1                                       Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 2                                Reminds Me Of You  5YSHygGN9D0mID1NsVd5my
# 3                              Coco (feat. DaBaby)  2V6pjeOCuPBVlatcWTXUtP
# 4  fools (can't help falling in love) (feat. Sody)  4VEEDnEFLI9dUy5QA51rom
#
#           artist               artist_id category  \
# 0  The Kid LAROI  2tIP7SsRs7vjIcLrU85W8J      pop
# 1  Glass Animals  4yvcSjfu4PC0CYQyLy4wSq      pop
# 2     Juice WRLD  4MCBfE4596Uoi2O4DtmEMz      pop
# 3       24kGoldn  6fWVd57NKTalqvmjRd2t8Z      pop
# 4         Foster  6vCIRD06VaQwwaZS0TqiCz      pop
#
#                           genres     filtered_genres new_genres
# 0                   [australian]        [australian]         []
# ...

# %%
# Create a DataFrame of songs with genres and no new_genres
need_to_fix0 = song_genres_df[song_genres_df['genres'].apply(lambda x: len(x)) > 0]
need_to_fix = need_to_fix0[song_genres_df['new_genres'].apply(lambda x: len(x)) == 0]
# Get the most popular filtered_genres for each category
#category_genres = {}
for category in filtered_categories:
    genres = []
    for index, row in need_to_fix[need_to_fix['category']==category].iterrows():
        genres.extend(row['filtered_genres'])
    unique_genres = list(set(genres))
    genre_counts = []
    for genre in unique_genres:
        genre_counts.append((genre, genres.count(genre)))
    print(category, sorted(genre_counts, key = lambda x: x[1], reverse=True)[0:5])   
    #category_genres[category] = sorted(genre_counts, key = lambda x: x[1], reverse=True)[0:5]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# pop [('modern', 24), ('uk', 19), ('social', 9), ('australian', 9), ('bedroom', 7)]
# hiphop [('rap', 190), ('hip', 169), ('trap', 101), ('southern', 79), ('underground', 67)]
# metal [('alternative', 118), ('nu', 95), ('melodic', 73), ('rap', 67), ('progressive', 64)]
# rock [('modern', 119), ('alternative', 98), ('nu', 65), ('emo', 48), ('post-grunge', 46)]
# jazz [('smooth', 120), ('contemporary', 81), ('vocal', 65), ('adult', 41), ('gypsy', 30)]
# rnb [('hip', 21), ('r&b', 21), ('new', 18), ('neo', 15), ('quiet', 12)]
# romance [('soft', 42), ('adult', 37), ('mellow', 33), ('quiet', 15), ('bubblegum', 13)]
# soul [('motown', 36), ('neo', 36), ('disco', 27), ('quiet', 25), ('classic', 19)]
# ...

# %%
# Create lists of audio features
t0 = time.time()
audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                  'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                  'duration_ms', 'time_signature']
danceability = [] 
energy = [] 
key = []
loudness = [] 
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []
time_signature = []
count = 0
for song_id in song_genres_df['song_id']:
    query_url = base_url + f'/v1/audio-features/{song_id}'
    features = requests.get(query_url, headers=headers_dict).json()
    try:
        danceability.append(features['danceability'])
        energy.append(features['energy'])
        key.append(features['key'])
        loudness.append(features['loudness'])
        mode.append(features['mode'])
        speechiness.append(features['speechiness'])
        acousticness.append(features['acousticness'])
        instrumentalness.append(features['instrumentalness'])
        liveness.append(features['liveness'])
        valence.append(features['valence'])
        tempo.append(features['tempo'])
        duration_ms.append(features['duration_ms'])
        time_signature.append(features['time_signature'])
    except(Exception) as e:
        print(e)
        print(song_id, features)
        danceability.append(None)
        energy.append(None)
        key.append(None)
        loudness.append(None)
        mode.append(None)
        speechiness.append(None)
        acousticness.append(None)
        instrumentalness.append(None)
        liveness.append(None)
        valence.append(None)
        tempo.append(None)
        duration_ms.append(None)
        time_signature.append(None)
    count+=1
    if count%1000 == 0:
        print(f'Features found for songs {count-1000}-{count}')

t1 = time.time()
print(f'Run time: {t1-t0} seconds')
print(f'Audio features added for {len(danceability)} songs.')
# Out:
# Features found for songs 0-1000
# 'danceability'
# 1M7uameaPY3xlxMde3WLFl {'error': {'status': 404, 'message': 'analysis not found'}}
# Features found for songs 1000-2000
# Features found for songs 2000-3000
# Features found for songs 3000-4000
# Features found for songs 4000-5000
# Features found for songs 5000-6000
# Features found for songs 6000-7000
# Features found for songs 7000-8000
# Features found for songs 8000-9000
# Features found for songs 9000-10000
# Features found for songs 10000-11000
# Features found for songs 11000-12000
# Features found for songs 12000-13000
# Features found for songs 13000-14000
# Run time: 1762.4801149368286 seconds
# Audio features added for 14212 songs.

# %%
# Add columns of audio features
song_genres_df['audio_ft_danceability'] = danceability
song_genres_df['audio_ft_energy'] = energy
song_genres_df['audio_ft_key'] = key
song_genres_df['audio_ft_loudness'] = loudness
song_genres_df['audio_ft_mode'] = mode
song_genres_df['audio_ft_speechiness'] = speechiness
song_genres_df['audio_ft_acousticness'] = acousticness
song_genres_df['audio_ft_instrumentalness'] = instrumentalness
song_genres_df['audio_ft_liveness'] = liveness
song_genres_df['audio_ft_valence'] = valence
song_genres_df['audio_ft_tempo'] = tempo
song_genres_df['audio_ft_duration_ms'] = duration_ms
song_genres_df['audio_ft_time_signature'] = time_signature
song_genres_df.head()
# Out:
# Run time: 0.050720930099487305 seconds
#                                     song                 song_id  \
# 0                                 willow  0lx2cLdOt3piJbcaXIV74f
# 1  Stay Next To Me (with Chelsea Cutler)  6SGG5AxHShqSYiV9fCWpZz
# 2                            WITHOUT YOU  27OeeYzk6klgBh83TSvGMA
# 3                             Heat Waves  3USxtqRwSYz57Ewm6wWRMp
# 4                                 r u ok  7rq1zCf90CnU7OalBLIgNp
#
#           artist               artist_id category  \
# 0   Taylor Swift  06HL4z0CvFAxyc27GXpf02      pop
# 1     Quinn XCII  3ApUX1o6oSz321MMECyIYd      pop
# 2  The Kid LAROI  2tIP7SsRs7vjIcLrU85W8J      pop
# 3  Glass Animals  4yvcSjfu4PC0CYQyLy4wSq      pop
# 4     Tate McRae  45dkTj5sMRSjrmBSBeiHym      pop
#
#                                 genres           filtered_genres  \
# 0                         [dance, pop]              [dance, pop]
# 1             [indie, pop, electropop]  [indie, pop, electropop]
# ...

# %%
# Save DataFrame to CSV
song_genres_df.drop(['filtered_genres', 'new_genres'], axis=1).to_csv('../Data/song_genres.csv', index=False)

# %%
# Create a dictionary of audio features
#t0 = time.time()
#audio_features = defaultdict(list)
#features_list = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
#                  'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
#                  'duration_ms', 'time_signature']
#for song_id in song_genres_df['song_id']:
#    query_url = base_url + f'/v1/audio-features/{song_id}'
#    features = requests.get(query_url, headers=headers_dict).json()
#    for feat in features_list:
#        audio_features[feat].append(features[feat])
#audio_features = dict(audio_features)

#t1 = time.time()
#print(f'Run time: {t1-t0} seconds')
#print(f'Audio features added for {len(danceability)} songs.')
#audio_features

# %%
# Create a list of all genres
genre_list = []
for artist_genres in genre_column:
    genre_list.extend(artist_genres)
genre_list = list(set(genre_list))
len(genre_list)

# %%
genre_list = ['afro' if genre.startswith('afro') else genre for genre in genre_list]
genre_list = ['arab' if genre.startswith('arab') else genre for genre in genre_list]
genre_list = ['bass' if genre.startswith('bass') else genre for genre in genre_list]
genre_list = ['british' if genre.startswith('brit') else genre for genre in genre_list]
genre_list = ['bubble' if genre.startswith('bubble') else genre for genre in genre_list]
genre_list = ['chill' if genre.startswith('chill') else genre for genre in genre_list]
genre_list = ['dance' if genre.startswith('dance') else genre for genre in genre_list]
genre_list = ['electric' if genre.startswith('electr') else genre for genre in genre_list]
genre_list = ['euro' if genre.startswith('euro') else genre for genre in genre_list]
genre_list = ['folk' if genre.startswith('folk') else genre for genre in genre_list]
genre_list = ['indie' if genre.startswith('indie') else genre for genre in genre_list]
genre_list = ['neo-classical' if genre.startswith('neoclassical') else genre for genre in genre_list]
genre_list = ['post' if genre.startswith('post') else genre for genre in genre_list]
genre_list = ['reggae' if genre.startswith('reggae') else genre for genre in genre_list]
genre_list = ['rock' if genre.startswith('rock') else genre for genre in genre_list]
genre_list = ['south' if genre.startswith('south') else genre for genre in genre_list]
genre_list = list(set(genre_list))
print(len(genre_list))
